#   inflating: lung_mask/coronacases_001.nii
#   inflating: lung_mask/coronacases_002.nii
#   inflating: lung_mask/coronacases_003.nii
#   inflating: lung_mask/coronacases_004.nii
#   inflating: lung_mask/coronacases_005.nii
#   inflating: lung_mask/coronacases_006.nii
#   inflating: lung_mask/coronacases_007.nii
#   inflating: lung_mask/coronacases_008.nii
#   inflating: lung_mask/coronacases_009.nii
#   inflating: lung_mask/coronacases_010.nii
#   inflating: lung_mask/radiopaedia_10_85902_1.nii
#   inflating: lung_mask/radiopaedia_10_85902_3.nii
#   inflating: lung_mask/radiopaedia_14_85914_0.nii
#   inflating: lung_mask/radiopaedia_27_86410_0.nii
#   inflating: lung_mask/radiopaedia_29_86490_1.nii
#   inflating: lung_mask/radiopaedia_29_86491_1.nii
#   inflating: lung_mask/radiopaedia_36_86526_0.nii
#   inflating: lung_mask/radiopaedia_40_86625_0.nii
#   inflating: lung_mask/radiopaedia_4_85506_1.nii
#   inflating: lung_mask/radiopaedia_7_85703_0.nii
#   inflating: metadata.csv

# %% [markdown]
# ### Convert .nii to .png

# %%
# import required libraries
import os, glob
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import numpy, shutil, os, nibabel
import sys, getopt
import glob
import imageio
inputfile = 'ct_scans'
outputfile = 'ct_scans_png/'
if not os.path.exists(outputfile):
    os.makedirs(outputfile)

for inputfile in glob.glob("ct_scans/*.nii"):
        image_array = nibabel.load(inputfile).get_fdata()
        nx, ny, nz = image_array.shape
        total_slices = image_array.shape[2]
        print(image_array.shape)
        print(image_array.dtype)
        data = numpy.rot90(image_array[:, :, 0])
        image_name = inputfile[:-4] + ".png"
        imageio.imsave(image_name, data.astype(numpy.float32))
        shutil.move(image_name, outputfile)
        
print('Finished converting images')
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1023.0, 2247.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 249)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 42)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1021.0, 1499.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1021.0, 1443.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 290)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [16.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 401, 110)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [17.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 93)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 418)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1021.0, 1597.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 42)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 45)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1023.0, 1834.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1023.0, 1711.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1021.0, 1632.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 45)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [14.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 66)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1021.0, 1640.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 256)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1023.0, 1931.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 213)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1021.0, 1292.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 270)
# float64
# Finished converting images

# %%
import numpy, shutil, os, nibabel
import sys, getopt
import glob
import imageio
inputfile = 'lung_mask'
outputfile = 'lung_mask_png/'
if not os.path.exists(outputfile):
    os.makedirs(outputfile)

for inputfile in glob.glob("lung_mask/*.nii"):
        image_array = nibabel.load(inputfile).get_fdata()
        nx, ny, nz = image_array.shape
        total_slices = image_array.shape[2]
        print(image_array.shape)
        print(image_array.dtype)
        data = image_array[:, :, 0]
        image_name = inputfile[:-4] + ".png"
        imageio.imsave(image_name, data.astype(numpy.float32))
        shutil.move(image_name, outputfile)
        
print('Finished converting images')
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 401, 110)
# float64
# (630, 630, 66)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# (512, 512, 301)
# float64
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 270)
# float64
# (630, 630, 93)
# float64
# (630, 630, 45)
# float64
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 256)
# float64
# (630, 630, 45)
# float64
# (512, 512, 290)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 249)
# float64
# (630, 630, 42)
# float64
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 213)
# float64
# (512, 512, 200)
# float64
# (630, 630, 42)
# float64
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 418)
# float64
# Finished converting images

# %%
import numpy, shutil, os, nibabel
import sys, getopt
import glob
import imageio
inputfile = 'infection_mask'
outputfile = 'infection_mask_png/'
if not os.path.exists(outputfile):
    os.makedirs(outputfile)

for inputfile in glob.glob("infection_mask/*.nii"):
        image_array = nibabel.load(inputfile).get_fdata()
        nx, ny, nz = image_array.shape
        total_slices = image_array.shape[2]
        print(image_array.shape)
        print(image_array.dtype)
        data = image_array[:, :, 0]
        image_name = inputfile[:-4] + ".png"
        imageio.imsave(image_name, data.astype(numpy.float32))
        shutil.move(image_name, outputfile)
        
print('Finished converting images')
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 401, 110)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 66)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 270)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 93)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 45)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 256)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 45)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 290)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 249)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 42)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 213)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 42)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 418)
# float64
# Finished converting images

# %%
import numpy, shutil, os, nibabel
import sys, getopt
import glob
import imageio
inputfile = 'lung_and_infection_mask'
outputfile = 'lung_and_infection_mask_png/'
if not os.path.exists(outputfile):
    os.makedirs(outputfile)

for inputfile in glob.glob("lung_and_infection_mask/*.nii"):
        image_array = nibabel.load(inputfile).get_fdata()
        nx, ny, nz = image_array.shape
        total_slices = image_array.shape[2]
        print(image_array.shape)
        print(image_array.dtype)
        data = image_array[:, :, 0]
        image_name = inputfile[:-4] + ".png"
        imageio.imsave(image_name, data.astype(numpy.float32))
        shutil.move(image_name, outputfile)
        
print('Finished converting images')
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 3.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 401, 110)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 66)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 270)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 93)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 3.0]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 45)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 256)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 45)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 290)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 249)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 42)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 301)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 213)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (512, 512, 200)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 42)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 39)
# float64
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# (630, 630, 418)
# float64
# Finished converting images

# %% [markdown]
# **Load data**

# %%
import cv2

# %%
# Upload the images from folder
import os
def load_images_from_folder(folder):
    train_image = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
          train_image.append(cv2.resize(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), (128,128)))          
    return train_image

# %%
ct_scans = load_images_from_folder('ct_scans_png')

# %%
lung_mask = load_images_from_folder('lung_mask_png')

# %%
infection_mask = load_images_from_folder('infection_mask_png')
lung_and_infection_mask = load_images_from_folder('lung_and_infection_mask_png')

# %%
train_image = ct_scans
train_label = lung_mask

# %%
CT = []
Mask = []
img_size = 128




for case in range(20): #Concat all cases to list
    ct = train_image[case]
    mask = train_label[case]
    
    for imgsize in range(ct.shape[2]): #Convert pixals to 1-d array
        
        ct_img = cv2.resize(ct[..., imgsize], dsize = (img_size, img_size),interpolation = cv2.INTER_AREA).astype('float64')
        mask_img = cv2.resize(mask[..., imgsize],dsize=(img_size, img_size),interpolation = cv2.INTER_AREA).astype('float64')
        CT.append(ct_img[..., np.newaxis])
        Mask.append(mask_img[..., np.newaxis])

# %%
CT = np.array(CT)
Mask = np.array(Mask)

# %%
fig = plt.figure(figsize = (18,15))

plt.subplot(1,2,1)
plt.imshow(CT[50][...,0], cmap = 'bone')
plt.title('original CT')

plt.subplot(1,2,2)
plt.imshow(CT[50][...,0], cmap = 'bone')
plt.imshow(Mask[20][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')
# Out:
# Text(0.5, 1.0, 'original infection mask')

# %%
mins = CT.min(axis=(1,2,3), keepdims=True)
maxs = CT.max(axis=(1,2,3), keepdims=True)
norm_data = (CT-mins)/(maxs-mins)

# %%
plt.figure(figsize = (9,9))

plt.imshow(norm_data[15][...,0], cmap = 'bone')

# %%
from sklearn.model_selection import train_test_split
CT_train, CT_test, Mask_train, Mask_test = train_test_split(norm_data, Mask, test_size = 0.1)

# %%
class attention_unet():
  def __init__(self,img_rows=128,img_cols=128):
    self.img_rows=img_rows
    self.img_cols=img_cols
    self.img_shape=(self.img_rows,self.img_cols,1)
    self.df=64
    self.uf=64
    
  def build_unet(self):
    def conv2d(layer_input,filters,dropout_rate=0,bn=False):
      d=layers.Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(layer_input)
      if bn:
        d=layers.BatchNormalization()(d)
      d=layers.Activation('relu')(d)
      
      d=layers.Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(d)
      if bn:
        d=layers.BatchNormalization()(d)
      d=layers.Activation('relu')(d)
      
      if dropout_rate:
        d=layers.Dropout(dropout_rate)(d)
      
      return d
    
    def deconv2d(layer_input,filters,bn=False):
      u=layers.UpSampling2D((2,2))(layer_input)
      u=layers.Conv2D(filters,kernel_size=(3,3),strides=(1,1),padding='same')(u)
      if bn:
        u=layers.BatchNormalization()(u)
      u=layers.Activation('relu')(u)
      
      return u
    
    def attention_block(F_g,F_l,F_int,bn=False):
      g=layers.Conv2D(F_int,kernel_size=(1,1),strides=(1,1),padding='valid')(F_g)
      if bn:
        g=layers.BatchNormalization()(g)
      x=layers.Conv2D(F_int,kernel_size=(1,1),strides=(1,1),padding='valid')(F_l)
      if bn:
        x=layers.BatchNormalization()(x)
#       print(g.shape)
#       print(x.shape)
      psi=layers.Add()([g,x])
      psi=layers.Activation('relu')(psi)
      
      psi=layers.Conv2D(1,kernel_size=(1,1),strides=(1,1),padding='valid')(psi)
      
      if bn:
        psi=layers.BatchNormalization()(psi)
      psi=layers.Activation('sigmoid')(psi)
      
      return layers.Multiply()([F_l,psi])
    
    inputs=layers.Input(shape=self.img_shape)
    
    conv1=conv2d(inputs,self.df)
    pool1=layers.MaxPooling2D((2,2))(conv1)
    
    conv2=conv2d(pool1,self.df*2,bn=True)
    pool2=layers.MaxPooling2D((2,2))(conv2)
    
    conv3=conv2d(pool2,self.df*4,bn=True)
    pool3=layers.MaxPooling2D((2,2))(conv3)
    
    conv4=conv2d(pool3,self.df*8,dropout_rate=0.5,bn=True)
    pool4=layers.MaxPooling2D((2,2))(conv4)
    
    conv5=conv2d(pool4,self.df*16,dropout_rate=0.5,bn=True)
    
    up6=deconv2d(conv5,self.uf*8,bn=True)
    conv6=attention_block(up6,conv4,self.uf*8,bn=True)
    up6=layers.Concatenate()([up6,conv6])
    conv6=conv2d(up6,self.uf*8)
    
    up7=deconv2d(conv6,self.uf*4,bn=True)
    conv7=attention_block(up7,conv3,self.uf*4,bn=True)
    up7=layers.Concatenate()([up7,conv7])
    conv7=conv2d(up7,self.uf*4)
    
    up8=deconv2d(conv7,self.uf*2,bn=True)
    conv8=attention_block(up8,conv2,self.uf*2,bn=True)
    up8=layers.Concatenate()([up8,conv8])
    conv8=conv2d(up8,self.uf*2)
    
    up9=deconv2d(conv8,self.uf,bn=True)
    conv9=attention_block(up9,conv1,self.uf,bn=True)
    up9=layers.Concatenate()([up9,conv9])
    conv9=conv2d(up9,self.uf)
    
    outputs=layers.Conv2D(1,kernel_size=(1,1),strides=(1,1),activation='sigmoid')(conv9)
    
    model=Model(inputs=inputs,outputs=outputs)
    
    return model

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("best_model.model", monitor='loss', verbose=1,
    save_best_only=True, mode='auto', period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
import keras.layers as layers
from keras.models import Model



# batchnormalization
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x
# block
def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x
# residual_block
def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
from keras.losses import binary_crossentropy
from keras import backend as K

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(
            y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss

# %%
from keras.optimizers import Adam

def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# %%
from keras.callbacks import ModelCheckpoint, Callback


class AlphaScheduler(Callback):
  def init(self, alpha, update_fn):
    self.alpha = alpha
    self.update_fn = update_fn
  def on_epoch_end(self, epoch, logs=None):
    updated_alpha = self.update_fn(K.get_value(self.alpha))

alpha = K.variable(1, dtype='float32')

def update_alpha(value):
  return np.clip(value - 0.01, 0.01, 1)

# %%
def gl_sl_wrapper(alpha):
    def gl_sl(y_true, y_pred):
        return alpha* weighted_bce_dice_loss(y_true, y_pred) +  (1-alpha)* surface_loss_keras(y_true, y_pred)
    return gl_sl

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('model')

checkpoint = ModelCheckpoint(weight_path, monitor='val_dice_coef', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_dice_coef', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='max', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_dice_coef", 
                      mode="max", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
Net=attention_unet()
unet=Net.build_unet()

unet.compile(loss='binary_crossentropy',
             optimizer=Adam(1e-4),
             metrics=['accuracy'])

unet.summary()
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 128, 128, 64) 640         input_11[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 128, 128, 64) 0           conv2d_350[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 128, 128, 64) 36928       activation_300[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 128, 128, 64) 0           conv2d_351[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 64, 64, 64)   0           activation_301[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 64, 64, 128)  512         conv2d_352[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 64, 64, 128)  0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 64, 64, 128)  147584      activation_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 64, 64, 128)  512         conv2d_353[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 64, 64, 128)  0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 32, 32, 128)  0           activation_303[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 32, 32, 256)  1024        conv2d_354[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 32, 32, 256)  0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 32, 32, 256)  590080      activation_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 32, 32, 256)  1024        conv2d_355[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 32, 32, 256)  0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 16, 16, 256)  0           activation_305[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 16, 16, 512)  2048        conv2d_356[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 16, 16, 512)  0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 16, 16, 512)  2359808     activation_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 16, 16, 512)  2048        conv2d_357[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 16, 16, 512)  0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 16, 16, 512)  0           activation_307[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 8, 8, 512)    0           dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 8, 8, 1024)   4719616     max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 8, 8, 1024)   4096        conv2d_358[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 8, 8, 1024)   0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 8, 8, 1024)   9438208     activation_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 8, 8, 1024)   4096        conv2d_359[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 8, 8, 1024)   0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 8, 8, 1024)   0           activation_309[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_40 (UpSampling2D) (None, 16, 16, 1024) 0           dropout_21[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 16, 16, 512)  4719104     up_sampling2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 16, 16, 512)  2048        conv2d_360[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 16, 16, 512)  0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 16, 16, 512)  262656      activation_310[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 16, 16, 512)  262656      dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 16, 16, 512)  2048        conv2d_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 16, 16, 512)  2048        conv2d_362[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 16, 16, 512)  0           batch_normalization_249[0][0]
#                                                                  batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 16, 16, 512)  0           add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 16, 16, 1)    513         activation_311[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 16, 16, 1)    4           conv2d_363[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 16, 16, 1)    0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 16, 16, 512)  0           dropout_20[0][0]
#                                                                  activation_312[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 16, 16, 1024) 0           activation_310[0][0]
#                                                                  multiply_40[0][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, 16, 16, 512)  4719104     concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 16, 16, 512)  0           conv2d_364[0][0]
# __________________________________________________________________________________________________
# conv2d_365 (Conv2D)             (None, 16, 16, 512)  2359808     activation_313[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 16, 16, 512)  0           conv2d_365[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_41 (UpSampling2D) (None, 32, 32, 512)  0           activation_314[0][0]
# __________________________________________________________________________________________________
# conv2d_366 (Conv2D)             (None, 32, 32, 256)  1179904     up_sampling2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 32, 32, 256)  1024        conv2d_366[0][0]
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, 32, 32, 256)  0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# conv2d_367 (Conv2D)             (None, 32, 32, 256)  65792       activation_315[0][0]
# __________________________________________________________________________________________________
# conv2d_368 (Conv2D)             (None, 32, 32, 256)  65792       activation_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 32, 32, 256)  1024        conv2d_367[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 32, 32, 256)  1024        conv2d_368[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 32, 32, 256)  0           batch_normalization_253[0][0]
#                                                                  batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 32, 32, 256)  0           add_41[0][0]
# __________________________________________________________________________________________________
# conv2d_369 (Conv2D)             (None, 32, 32, 1)    257         activation_316[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 32, 32, 1)    4           conv2d_369[0][0]
# __________________________________________________________________________________________________
# activation_317 (Activation)     (None, 32, 32, 1)    0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 32, 32, 256)  0           activation_305[0][0]
#                                                                  activation_317[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 32, 32, 512)  0           activation_315[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# conv2d_370 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_318 (Activation)     (None, 32, 32, 256)  0           conv2d_370[0][0]
# __________________________________________________________________________________________________
# conv2d_371 (Conv2D)             (None, 32, 32, 256)  590080      activation_318[0][0]
# __________________________________________________________________________________________________
# activation_319 (Activation)     (None, 32, 32, 256)  0           conv2d_371[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_42 (UpSampling2D) (None, 64, 64, 256)  0           activation_319[0][0]
# __________________________________________________________________________________________________
# conv2d_372 (Conv2D)             (None, 64, 64, 128)  295040      up_sampling2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 64, 64, 128)  512         conv2d_372[0][0]
# __________________________________________________________________________________________________
# activation_320 (Activation)     (None, 64, 64, 128)  0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_373 (Conv2D)             (None, 64, 64, 128)  16512       activation_320[0][0]
# __________________________________________________________________________________________________
# conv2d_374 (Conv2D)             (None, 64, 64, 128)  16512       activation_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 64, 64, 128)  512         conv2d_373[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 64, 64, 128)  512         conv2d_374[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 64, 64, 128)  0           batch_normalization_257[0][0]
#                                                                  batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# activation_321 (Activation)     (None, 64, 64, 128)  0           add_42[0][0]
# __________________________________________________________________________________________________
# conv2d_375 (Conv2D)             (None, 64, 64, 1)    129         activation_321[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 64, 64, 1)    4           conv2d_375[0][0]
# __________________________________________________________________________________________________
# activation_322 (Activation)     (None, 64, 64, 1)    0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 64, 64, 128)  0           activation_303[0][0]
#                                                                  activation_322[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 64, 64, 256)  0           activation_320[0][0]
#                                                                  multiply_42[0][0]
# __________________________________________________________________________________________________
# conv2d_376 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_42[0][0]
# __________________________________________________________________________________________________
# activation_323 (Activation)     (None, 64, 64, 128)  0           conv2d_376[0][0]
# __________________________________________________________________________________________________
# conv2d_377 (Conv2D)             (None, 64, 64, 128)  147584      activation_323[0][0]
# __________________________________________________________________________________________________
# activation_324 (Activation)     (None, 64, 64, 128)  0           conv2d_377[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_43 (UpSampling2D) (None, 128, 128, 128 0           activation_324[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, 128, 128, 64) 73792       up_sampling2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 128, 128, 64) 256         conv2d_378[0][0]
# __________________________________________________________________________________________________
# activation_325 (Activation)     (None, 128, 128, 64) 0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_379 (Conv2D)             (None, 128, 128, 64) 4160        activation_325[0][0]
# __________________________________________________________________________________________________
# conv2d_380 (Conv2D)             (None, 128, 128, 64) 4160        activation_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 128, 128, 64) 256         conv2d_379[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 128, 128, 64) 256         conv2d_380[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 128, 128, 64) 0           batch_normalization_261[0][0]
#                                                                  batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# activation_326 (Activation)     (None, 128, 128, 64) 0           add_43[0][0]
# __________________________________________________________________________________________________
# conv2d_381 (Conv2D)             (None, 128, 128, 1)  65          activation_326[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 128, 128, 1)  4           conv2d_381[0][0]
# __________________________________________________________________________________________________
# activation_327 (Activation)     (None, 128, 128, 1)  0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 128, 128, 64) 0           activation_301[0][0]
#                                                                  activation_327[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 128, 128, 128 0           activation_325[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# conv2d_382 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_43[0][0]
# __________________________________________________________________________________________________
# activation_328 (Activation)     (None, 128, 128, 64) 0           conv2d_382[0][0]
# __________________________________________________________________________________________________
# conv2d_383 (Conv2D)             (None, 128, 128, 64) 36928       activation_328[0][0]
# __________________________________________________________________________________________________
# activation_329 (Activation)     (None, 128, 128, 64) 0           conv2d_383[0][0]
# __________________________________________________________________________________________________
# conv2d_384 (Conv2D)             (None, 128, 128, 1)  65          activation_329[0][0]
# ==================================================================================================
# Total params: 35,238,293
# Trainable params: 35,224,845
# Non-trainable params: 13,448
# __________________________________________________________________________________________________

# %%
unet.fit(CT_train, Mask_train, epochs = 50, validation_split=0.1 ,verbose=1,shuffle=True, callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 2/2 [==============================] - ETA: 0s - loss: -1321.3058 - accuracy: 0.9759WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1005s vs `on_train_batch_end` time: 0.1989s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1005s vs `on_train_batch_end` time: 0.1989s). Check your callbacks.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 381ms/step - loss: -1321.3058 - accuracy: 0.9759 - val_loss: 0.9878 - val_accuracy: 0.9955
# Epoch 2/50
# 2/2 [==============================] - ETA: 0s - loss: -1405.2076 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 369ms/step - loss: -1405.2076 - accuracy: 0.9750 - val_loss: 0.9992 - val_accuracy: 0.9955
# Epoch 3/50
# 2/2 [==============================] - ETA: 0s - loss: -1438.4777 - accuracy: 0.9661WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 367ms/step - loss: -1438.4777 - accuracy: 0.9661 - val_loss: 1.0297 - val_accuracy: 0.9955
# Epoch 4/50
# 2/2 [==============================] - ETA: 0s - loss: -1570.2192 - accuracy: 0.9752WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 369ms/step - loss: -1570.2192 - accuracy: 0.9752 - val_loss: 1.0712 - val_accuracy: 0.9955
# Epoch 5/50
# 2/2 [==============================] - ETA: 0s - loss: -1619.4518 - accuracy: 0.9760WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 368ms/step - loss: -1619.4518 - accuracy: 0.9760 - val_loss: 1.1088 - val_accuracy: 0.9955
# Epoch 6/50
# 2/2 [==============================] - ETA: 0s - loss: -1746.8981 - accuracy: 0.9785WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 367ms/step - loss: -1746.8981 - accuracy: 0.9785 - val_loss: 1.1304 - val_accuracy: 0.9955
# Epoch 7/50
# 2/2 [==============================] - ETA: 0s - loss: -1589.5518 - accuracy: 0.9658WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 367ms/step - loss: -1589.5518 - accuracy: 0.9658 - val_loss: 1.1649 - val_accuracy: 0.9955
# Epoch 8/50
# 2/2 [==============================] - ETA: 0s - loss: -1881.8989 - accuracy: 0.9753WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s
ARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# 2/2 [==============================] - 1s 385ms/step - loss: -9179.4082 - accuracy: 0.9785 - val_loss: 0.7011 - val_accuracy: 0.9899

# %%
unet.evaluate(CT_test, Mask_test)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2371 - accuracy: 0.8079
# [0.2371167689561844, 0.8079121708869934]

# %%
predicted = unet.predict(CT_test)
fig = plt.figure(figsize = (18,15))

plt.subplot(1,3,1)
plt.imshow(CT_test[5][...,0], cmap = 'bone')
plt.title('original CT image')

plt.subplot(1,3,2)
plt.imshow(CT_test[5][...,0], cmap = 'bone')
plt.imshow(Mask_test[5][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(CT_test[5][...,0], cmap = 'bone')
plt.imshow(predicted[5][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %%
predicted = unet.predict(CT_test)
fig = plt.figure(figsize = (18,15))

plt.subplot(1,3,1)
plt.imshow(CT_test[1][...,0], cmap = 'bone')
plt.title('original CT image')

plt.subplot(1,3,2)
plt.imshow(CT_test[1][...,0], cmap = 'bone')
plt.imshow(Mask_test[1][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(CT_test[1][...,0], cmap = 'bone')
plt.imshow(predicted[1][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %%
predicted = unet.predict(CT_test)
fig = plt.figure(figsize = (18,15))

plt.subplot(1,3,1)
plt.imshow(CT_test[2][...,0], cmap = 'bone')
plt.title('original CT image')

plt.subplot(1,3,2)
plt.imshow(CT_test[2][...,0], cmap = 'bone')
plt.imshow(Mask_test[2][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(CT_test[2][...,0], cmap = 'bone')
plt.imshow(predicted[2][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %%
predicted = unet.predict(CT_test)
fig = plt.figure(figsize = (18,15))

plt.subplot(1,3,1)
plt.imshow(CT_test[3][...,0], cmap = 'bone')
plt.title('original CT image')

plt.subplot(1,3,2)
plt.imshow(CT_test[3][...,0], cmap = 'bone')
plt.imshow(Mask_test[3][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(CT_test[3][...,0], cmap = 'bone')
plt.imshow(predicted[3][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')

# %%
predicted = unet.predict(CT_test)
fig = plt.figure(figsize = (18,15))

plt.subplot(1,3,1)
plt.imshow(CT_test[4][...,0], cmap = 'bone')
plt.title('original CT image')

plt.subplot(1,3,2)
plt.imshow(CT_test[4][...,0], cmap = 'bone')
plt.imshow(Mask_test[4][...,0],alpha = 0.5, cmap = "nipy_spectral")
plt.title('original infection mask')

plt.subplot(1,3,3)
plt.imshow(CT_test[4][...,0], cmap = 'bone')
plt.imshow(predicted[4][...,0],alpha = 0.5,cmap = "nipy_spectral")
plt.title('predicted infection mask')
# Out:
# Text(0.5, 1.0, 'predicted infection mask')
